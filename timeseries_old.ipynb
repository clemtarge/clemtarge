# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, MinMaxScaler, PowerTransformer

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, matthews_corrcoef

from xgboost import XGBRegressor

from statsmodels.api import datasets

# %%
# df = pd.read_csv("climate/DailyDelhiClimateTrain.csv")
# df_date = df.set_index("date")
# target = 'meantemp'

df = datasets.nile.load_pandas().data
df_date = df.set_index("year")
target = "volume"

n, p = df_date.shape
df_date
# Out:
#         volume
# year
# 1871.0  1120.0
# 1872.0  1160.0
# 1873.0   963.0
# 1874.0  1210.0
# 1875.0  1160.0
# ...        ...
# 1966.0   746.0
# 1967.0   919.0
# 1968.0   718.0
# 1969.0   714.0
# 1970.0   740.0
#
# [100 rows x 1 columns]

# %%
df_date.plot(subplots=True, figsize=(16,3*p));

# %%
plt.rcParams["figure.figsize"] = (15,9)
sd = seasonal_decompose(df[target].to_list(), period=24, model='add')
sd.plot();

# %%
residuals = pd.DataFrame(sd.resid).dropna()
fig, ax = plt.subplots(1,2, figsize=(16,6))
residuals.plot(title="Residuals", legend=False, ax=ax[0])
residuals.plot(kind='kde', title='Density', legend=False, ax=ax[1]);

# %% [markdown]
# # ARIMA
# https://www.statsmodels.org/dev/generated/statsmodels.tsa.arima.model.ARIMA.html?highlight=arima#statsmodels.tsa.arima.model.ARIMA
#
# Find `(p,d,q)` coefficients
#
# ## Split data (train, test)

# %%
y_train, y_test = train_test_split(df[target], test_size=0.25, shuffle=False)
pd.DataFrame([y_train, y_test]).T.plot(figsize=(17,7))
plt.legend(['train', 'test']);

# %% [markdown]
# `p` coef in **AR** term
#
# * Keep the most significant lags (above the significance line)

# %%
fig, ax = plt.subplots(1, figsize=(17,6))
ax.grid(axis='x')
ax.set_xticks(np.arange(0,31,5))
plot_pacf(y_train.diff().dropna(), method="ywm", ax=ax);

# %% [markdown]
# `d` coef in **I** term
#
# * Differenciate the series until stationarity
# * Augmented Dickey Fuller test tests non-stationarity of the series
# $H_0$: non stationary serie
# $H_1$: stationary serie

# %%
serie = y_train#.diff().dropna()
print(f"p-value: {adfuller(serie)[1]:.3e}")
serie.plot(figsize=(17,6));
# Out:
# p-value: 1.399e-02

# %% [markdown]
# `q` coef in **MA** term
#
# * Keep the most significant lags (above the significance line)

# %%
fig, ax = plt.subplots(1, figsize=(17,6))
ax.grid(axis="x")
ax.set_xticks(np.arange(0,31,5))
plot_acf(y_train.diff().dropna(), ax=ax);

# %% [markdown]
# ### Find ARIMA coefficients  automatically

# %%
import pmdarima as pm

model = pm.auto_arima(y_train, 
                      test='adf',           # use adftest to find optimal 'd'
                      start_p=1, start_q=1, # minimum p and q
                      max_p=3, max_q=3,     # maximum p and q
                      m=1,                  # frequency of series
                      d=None,               # let model determine 'd'
                      seasonal=False,       # seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=976.515, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=966.164, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=956.801, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=974.561, Time=0.02 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=955.897, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=954.775, Time=0.20 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=964.291, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=956.499, Time=0.29 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=956.572, Time=0.31 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=955.428, Time=0.20 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=963.158, Time=0.14 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=958.477, Time=0.47 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 3.587 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   75
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -474.388
# Date:                Fri, 06 May 2022   AIC                            954.775
# Time:                        09:54:47   BIC                            961.687
# Sample:                             0   HQIC                           957.533
#                                  - 75
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2658      0.147      1.809      0.070      -0.022       0.554
# ma.L1         -0.8641      0.069    -12.602      0.000      -0.999      -0.730
# sigma2       2.14e+04   3554.217      6.022      0.000    1.44e+04    2.84e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.17   Jarque-Bera (JB):                 0.31
# Prob(Q):                              0.68   Prob(JB):                         0.86
# Heteroskedasticity (H):               0.48   Skew:                            -0.15
# Prob(H) (two-sided):                  0.07   Kurtosis:                         2.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model = ARIMA(y_train,order=(1,1,1))#, seasonal_order=(1,1,3,12))
# model = SARIMAX(df[target],order=(1,1,1),seasonal_order=(1,0,1,12))

model_arima = model.fit()
model_arima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 volume   No. Observations:                   75
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -474.388
# Date:                Fri, 06 May 2022   AIC                            954.775
# Time:                        09:54:47   BIC                            961.687
# Sample:                             0   HQIC                           957.533
#                                  - 75
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2658      0.147      1.809      0.070      -0.022       0.554
# ma.L1         -0.8641      0.069    -12.602      0.000      -0.999      -0.730
# sigma2       2.14e+04   3554.217      6.022      0.000    1.44e+04    2.84e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.17   Jarque-Bera (JB):                 0.31
# Prob(Q):                              0.68   Prob(JB):                         0.86
# Heteroskedasticity (H):               0.48   Skew:                            -0.15
# Prob(H) (two-sided):                  0.07   Kurtosis:                         2.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
n0 = n*3//4
predictions = model_arima.predict(start=n0, end=n-1, dynamic=False).rename('ARIMA Predictions')

y_test.plot(legend=True, figsize=(15,7))
predictions.plot(legend=True)
plt.legend(["y_test", "forecasted"])
plt.autoscale(axis='x',tight=True);

# %%
print(f"mape: {mean_absolute_percentage_error(df[target].iloc[n0:], predictions):.4f}")

print(f"correlation: {np.corrcoef(df[target].iloc[n0:], predictions)[0,1]:.3f}")
error = mean_absolute_error(df[target].iloc[n0:], predictions)
print(f"mse: {error:.3e}")
df[target].iloc[n0:].mean()
# Out:
# mape: 0.1181
# correlation: -0.263
# mse: 1.103e+02
# 882.12

# %%
res = model_arima.get_forecast(25).summary_frame(alpha=0.05)
print(res)

y_test.plot(legend=True, figsize=(16,7))
plt.plot(res["mean"]);
plt.autoscale(axis='x',tight=True)
plt.fill_between(res["mean"].index, res["mean_ci_lower"], res["mean_ci_upper"], color='b', alpha=.1)
plt.legend(['observed', 'forecast']);
# Out:
# volume        mean     mean_se  mean_ci_lower  mean_ci_upper
# 75      805.716286  146.298977     518.975559    1092.457013
# 76      806.970098  157.662772     497.956743    1115.983454
# 77      807.303421  161.610748     490.552175    1124.054667
# 78      807.392034  164.248412     485.471062    1129.313006
# 79      807.415592  166.563280     480.957561    1133.873623
# 80      807.421855  168.775313     476.628319    1138.215390
# 81      807.423519  170.940250     472.386787    1142.460252
# 82      807.423962  173.073269     468.206588    1146.641336
# 83      807.424080  175.179049     464.079453    1150.768706
# 84      807.424111  177.259481     460.001913    1154.846309
# 85      807.424119  179.315689     455.971826    1158.876412
# 86      807.424122  181.348562     451.987471    1162.860772
# 87      807.424122  183.358892     448.047297    1166.800947
# 88      807.424122  185.347417     444.149860    1170.698385
# 89      807.424122  187.314833     440.293795    1174.554449
# 90      807.424122  189.261798     436.477814    1178.370431
# 91      807.424122  191.188938     432.700690    1182.147554
# 92      807.424122  193.096845     428.961261    1185.886983
# 93      807.424122  194.986084     425.258420    1189.589824
# 94      807.424122  196.857193     421.591114    1193.257131
# 95      807.424122  198.710684     417.958338    1196.889907
# 96      807.424122  200.547046     414.359135    1200.489109
# 97      807.424122  202.366744     410.792592    1204.055653
# 98      807.424122  204.170225     407.257835    1207.590410
# 99      807.424122  205.957914     403.754029    1211.094216

# %% [markdown]
# # ML approach
#
# ### Preprocessing
#
# #### Lag differencing
#
# Can be use to remove seasonality if `lag` period is **T**
#
# `lag` can be set to :
# * 12 for monthly data
# * ...

# %%
lag = 1
# df[target] = df[target].diff(lag)
df[target]
# Out:
# 0      5.280355
# 1      5.279525
# 2      5.279833
# 3      5.279738
# 4      5.280046
#          ...
# 995    5.280046
# 996    5.280556
# 997    5.280046
# 998    5.280355
# 999    5.280971
# Name: amplitude, Length: 1000, dtype: float64

# %% [markdown]
# #### Transform data
#
# On a time series dataset, this can have the effect of removing a change in variance over time.

# %%
# pt = PowerTransformer()
# df[target] = pt.fit_transform(df[target].to_frame())

# %% [markdown]
# #### Scale data

# %%
# scaler = [StandardScaler(), MinMaxScaler()][1]
# df[target] = scaler.fit_transform(df[target].to_frame())

# %% [markdown]
# ### Prepare data

# %%
def series_to_supervised(time_series, n_steps_in, n_steps_out, forecast_inputs=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        time_series: Sequence of observations as a list or NumPy array
        n_steps_in: Number of lag observations as input (X)
        n_steps_out: Number of observations as output (y)
        forecast_inputs: whether to forecast inputs (True) or forecast output from inputs (False)
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    def getXcols(cols):
        return list(np.array([list(map(lambda x: x + f'(t-{i})', cols)) for i in range (n_steps_in,0,-1)]).flatten())
    def getYcols(cols):
        return list(np.array([list(map(lambda x: x + '(t' + f'+{i})'*(i!=0)+')'*(i==0), cols)) for i in range (0,n_steps_out)]).flatten())
    
    cols = time_series.columns
    if forecast_inputs:
        new_cols_x = getXcols(cols)
        new_cols_y = getYcols(cols)
    else:
        new_cols_x = getXcols(cols[:-1])
        new_cols_y = getYcols(cols[-1:])
        
    n_inputs = len(new_cols_x)
    n_outputs = len(new_cols_y)
    n_features = n_outputs // n_steps_out

    X, y = [], []
    for i in range(len(time_series)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        # check if we are beyond the dataset
        if out_end_ix > len(time_series):
            break
        # gather input and output parts of the pattern
        if forecast_inputs:
            seq_x, seq_y = time_series.iloc[i:end_ix, :], time_series.iloc[end_ix:out_end_ix, :]
        else:
            seq_x, seq_y = time_series.iloc[i:end_ix, :-1], time_series.iloc[end_ix-1:out_end_ix-1, -1]
        
        X.append(seq_x.to_numpy().flatten())
        y.append(seq_y.to_numpy().flatten())
    
    return [pd.concat([pd.DataFrame(X, columns=new_cols_x), pd.DataFrame(y, columns=new_cols_y)], axis=1),
            n_inputs,
            n_outputs,
           n_features]

df.dropna(inplace=True)
n_steps_in = 5
n_steps_out = 1
per_train = 0.7
time_series = df[[target]]
time_series_train = time_series[:int(n*per_train)]
time_series_test = time_series[int(n*per_train):]

# data, n_inputs, n_outputs, n_features = series_to_supervised(time_series, n_steps_in, n_steps_out, True)
# train, test = train_test_split(data, test_size=0.33, shuffle=False) # test_size dépend de n_previous à cause du dropna
# train, test = data[:int(n*per_train)], data[int(n*per_train):]

train, n_inputs, n_outputs, n_features = series_to_supervised(time_series_train, n_steps_in, n_steps_out, True)
test, _, _, _ = series_to_supervised(time_series_test, n_steps_in, n_steps_out, True)

scaler = [StandardScaler(), MinMaxScaler()][1]
train_scaled = pd.DataFrame(scaler.fit_transform(train))
test_scaled = pd.DataFrame(scaler.transform(test))

x_train, y_train = train_scaled.iloc[:,:-n_outputs], train_scaled.iloc[:,-n_outputs:]
x_test, y_test = test_scaled.iloc[:,:-n_outputs], test_scaled.iloc[:,-n_outputs:]
train
# Out:
#      amplitude(t-5)  amplitude(t-4)  amplitude(t-3)  amplitude(t-2)  \
# 0          5.280355        5.279525        5.279833        5.279738
# 1          5.279525        5.279833        5.279738        5.280046
# 2          5.279833        5.279738        5.280046        5.279430
# 3          5.279738        5.280046        5.279430        5.279122
# 4          5.280046        5.279430        5.279122        5.279940
# ..              ...             ...             ...             ...
# 690        5.280153        5.280461        5.280153        5.280153
# 691        5.280461        5.280153        5.280153        5.279940
# 692        5.280153        5.280153        5.279940        5.280770
# 693        5.280153        5.279940        5.280770        5.279738
# 694        5.279940        5.280770        5.279738        5.280556
#
#      amplitude(t-1)  amplitude(t)
# 0          5.280046      5.279430
# 1          5.279430      5.279122
# 2          5.279122      5.279940
# 3          5.279940      5.279323
# 4          5.279323      5.279525
# ..              ...           ...
# 690        5.279940      5.280770
# 691        5.280770      5.279738
# 692        5.279738      5.280556
# 693        5.280556      5.280355
# 694        5.280355      5.279940
#
# [695 rows x 6 columns]

# %% [markdown]
# #### XGBoost

# %%
model_xgb = XGBRegressor(objective='reg:squarederror', n_estimators=500)
model_xgb.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=500, n_jobs=32,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

model_rf = RandomForestRegressor(n_estimators=500)
model_rf.fit(x_train, y_train)
# Out:
# /data/appli_PITSI/users/targe/miniconda3/envs/dev2/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# RandomForestRegressor(n_estimators=500)

# %% [markdown]
# #### LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM

x_train_reshaped = x_train.to_numpy().reshape((x_train.shape[0], x_train.shape[1]//n_features, n_features))

model_lstm = Sequential()
model_lstm.add(LSTM(units =64, activation='relu', return_sequences=True, input_shape = (n_steps_in, n_features)))
model_lstm.add(Dropout(0.2))
model_lstm.add(LSTM(units =64, activation='relu', return_sequences=True))
model_lstm.add(Dropout(0.2))
model_lstm.add(LSTM(units =64, activation='relu', return_sequences=False))
model_lstm.add(Dropout(0.2))
model_lstm.add(Dense(units=n_outputs)) # Prediction of the next value

model_lstm.compile(optimizer='adam', loss='mae')
model_lstm.summary()

history = model_lstm.fit(x_train_reshaped, y_train, epochs = 30, batch_size=16, validation_split=0.1, verbose=1)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 5, 64)             16896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 5, 64)             0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 5, 64)             33024
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 5, 64)             0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 83,009
# Trainable params: 83,009
# Non-trainable params: 0
# _________________________________________________________________
# Train on 625 samples, validate on 70 samples
# Epoch 1/30
# 625/625 [==============================] - 6s 10ms/step - loss: 0.2528 - val_loss: 0.1936
# Epoch 2/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1362 - val_loss: 0.1226
# Epoch 3/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1342 - val_loss: 0.1633
# Epoch 4/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1328 - val_loss: 0.1379
# Epoch 5/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1319 - val_loss: 0.1404
# Epoch 6/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1311 - val_loss: 0.1266
# Epoch 7/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1294 - val_loss: 0.1235
# Epoch 8/30
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1334 - val_loss: 0.1240
# Epoch 9/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1359 - val_loss: 0.1238
# Epoch 10/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1307 - val_loss: 0.1376
# Epoch 11/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1324 - val_loss: 0.1391
# Epoch 12/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1349 - val_loss: 0.1491
# Epoch 13/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1324 - val_loss: 0.1400
# Epoch 14/30
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1320 - val_loss: 0.1372
# Epoch 15/30
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1298 - val_loss: 0.1406
# Epoch 16/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1330 - val_loss: 0.1433
# Epoch 17/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1298 - val_loss: 0.1316
# Epoch 18/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1319 - val_loss: 0.1333
# Epoch 19/30
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1324 - val_loss: 0.1308
# Epoch 20/30
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1307 - val_loss: 0.1353
# Epoch 21/30
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1295 - val_loss: 0.1382
# Epoch 22/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1267 - val_loss: 0.1329
# Epoch 23/30
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1300 - val_loss: 0.1555
# Epoch 24/30
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1276 - val_loss: 0.1195
# Epoch 25/30
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1360 - val_loss: 0.1337
# Epoch 26/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1301 - val_loss: 0.1436
# Epoch 27/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1270 - val_loss: 0.1433
# Epoch 28/30
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1297 - val_loss: 0.1335
# Epoch 29/30
# 625/625 [==============================] - 2s 3ms/step - loss: 0.1269 - val_loss: 0.1698
# Epoch 30/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1320 - val_loss: 0.1288

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch');
plt.legend(['train', 'val'], loc='upper left');

# %% [markdown]
# #### CNN

# %%
# multivariate output multi-step 1d cnn example
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.utils import plot_model

x_train_reshaped = x_train.to_numpy().reshape((x_train.shape[0], x_train.shape[1]//n_features, n_features))

model_nn = Sequential()
model_nn.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_steps_in, n_features)))
model_nn.add(MaxPooling1D(pool_size=2))
model_nn.add(Flatten())
model_nn.add(Dense(30, activation='relu'))
model_nn.add(Dense(30, activation='relu'))
model_nn.add(Dense(n_outputs))
model_nn.compile(optimizer='adam', loss='mae')
# fit model
model_nn.summary()
history = model_nn.fit(x_train_reshaped, y_train, epochs=50, verbose=1, validation_split=0.1)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 3, 64)             256
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 1, 64)             0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 30)                1950
# _________________________________________________________________
# dense_23 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 3,167
# Trainable params: 3,167
# Non-trainable params: 0
# _________________________________________________________________
# Train on 625 samples, validate on 70 samples
# Epoch 1/50
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3713 - val_loss: 0.2110
# Epoch 2/50
# 625/625 [==============================] - 1s 945us/step - loss: 0.1389 - val_loss: 0.1267
# Epoch 3/50
# 625/625 [==============================] - 0s 555us/step - loss: 0.1306 - val_loss: 0.1283
# Epoch 4/50
# 625/625 [==============================] - 0s 322us/step - loss: 0.1278 - val_loss: 0.1360
# Epoch 5/50
# 625/625 [==============================] - 0s 351us/step - loss: 0.1270 - val_loss: 0.1247
# Epoch 6/50
# 625/625 [==============================] - 0s 625us/step - loss: 0.1277 - val_loss: 0.1252
# Epoch 7/50
# 625/625 [==============================] - 0s 261us/step - loss: 0.1265 - val_loss: 0.1281
# Epoch 8/50
# 625/625 [==============================] - 0s 228us/step - loss: 0.1263 - val_loss: 0.1259
# Epoch 9/50
# 625/625 [==============================] - 0s 227us/step - loss: 0.1255 - val_loss: 0.1267
# Epoch 10/50
# 625/625 [==============================] - 0s 249us/step - loss: 0.1254 - val_loss: 0.1276
# Epoch 11/50
# 625/625 [==============================] - 0s 311us/step - loss: 0.1265 - val_loss: 0.1309
# Epoch 12/50
# 625/625 [==============================] - 0s 340us/step - loss: 0.1256 - val_loss: 0.1291
# Epoch 13/50
# 625/625 [==============================] - 0s 195us/step - loss: 0.1246 - val_loss: 0.1394
# Epoch 14/50
# 625/625 [==============================] - 0s 181us/step - loss: 0.1261 - val_loss: 0.1299
# Epoch 15/50
# 625/625 [==============================] - 0s 209us/step - loss: 0.1246 - val_loss: 0.1310
# Epoch 16/50
# 625/625 [==============================] - 0s 708us/step - loss: 0.1247 - val_loss: 0.1458
# Epoch 17/50
# 625/625 [==============================] - 0s 373us/step - loss: 0.1241 - val_loss: 0.1344
# Epoch 18/50
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1233 - val_loss: 0.1429
# Epoch 19/50
# 625/625 [==============================] - 0s 742us/step - loss: 0.1241 - val_loss: 0.1301
# Epoch 20/50
# 625/625 [==============================] - 1s 957us/step - loss: 0.1244 - val_loss: 0.1368
# Epoch 21/50
# 625/625 [==============================] - 0s 715us/step - loss: 0.1236 - val_loss: 0.1333
# Epoch 22/50
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1234 - val_loss: 0.1372
# Epoch 23/50
# 625/625 [==============================] - 0s 761us/step - loss: 0.1242 - val_loss: 0.1420
# Epoch 24/50
# 625/625 [==============================] - 1s 920us/step - loss: 0.1241 - val_loss: 0.1325
# Epoch 25/50
# 625/625 [==============================] - 0s 693us/step - loss: 0.1233 - val_loss: 0.1341
# Epoch 26/50
# 625/625 [==============================] - 0s 765us/step - loss: 0.1250 - val_loss: 0.1320
# Epoch 27/50
# 625/625 [==============================] - 0s 752us/step - loss: 0.1257 - val_loss: 0.1343
# Epoch 28/50
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1228 - val_loss: 0.1374
# Epoch 29/50
# 625/625 [==============================] - 0s 785us/step - loss: 0.1244 - val_loss: 0.1387
# Epoch 30/50
# 625/625 [==============================] - 0s 754us/step - loss: 0.1232 - val_loss: 0.1297
# Epoch 31/50
# 625/625 [==============================] - 0s 525us/step - loss: 0.1233 - val_loss: 0.1422
# Epoch 32/50
# 625/625 [==============================] - 0s 576us/step - loss: 0.1240 - val_loss: 0.1529
# Epoch 33/50
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1222 - val_loss: 0.1347
# Epoch 34/50
# 625/625 [==============================] - 0s 323us/step - loss: 0.1232 - val_loss: 0.1229
# Epoch 35/50
# 625/625 [==============================] - 0s 583us/step - loss: 0.1245 - val_loss: 0.1417
# Epoch 36/50
# 625/625 [==============================] - 0s 284us/step - loss: 0.1228 - val_loss: 0.1342
# Epoch 37/50
# 625/625 [==============================] - 0s 389us/step - loss: 0.1222 - val_loss: 0.1374
# Epoch 38/50
# 625/625 [==============================] - 0s 240us/step - loss: 0.1227 - val_loss: 0.1550
# Epoch 39/50
# 625/625 [==============================] - 0s 343us/step - loss: 0.1249 - val_loss: 0.1490
# Epoch 40/50
# 625/625 [==============================] - 0s 203us/step - loss: 0.1230 - val_loss: 0.1298
# Epoch 41/50
# 625/625 [==============================] - 0s 285us/step - loss: 0.1240 - val_loss: 0.1303
# Epoch 42/50
# 625/625 [==============================] - 0s 325us/step - loss: 0.1227 - val_loss: 0.1329
# Epoch 43/50
# 625/625 [==============================] - 0s 198us/step - loss: 0.1224 - val_loss: 0.1330
# Epoch 44/50
# 625/625 [==============================] - 0s 212us/step - loss: 0.1222 - val_loss: 0.1393
# Epoch 45/50
# 625/625 [==============================] - 0s 201us/step - loss: 0.1219 - val_loss: 0.1364
# Epoch 46/50
# 625/625 [==============================] - 0s 779us/step - loss: 0.1218 - val_loss: 0.1362
# Epoch 47/50
# 625/625 [==============================] - 0s 606us/step - loss: 0.1216 - val_loss: 0.1371
# Epoch 48/50
# 625/625 [==============================] - 0s 678us/step - loss: 0.1214 - val_loss: 0.1349
# Epoch 49/50
# 625/625 [==============================] - 0s 247us/step - loss: 0.1217 - val_loss: 0.1322
# Epoch 50/50
# 625/625 [==============================] - 0s 292us/step - loss: 0.1214 - val_loss: 0.1381

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch');
plt.legend(['train', 'val'], loc='upper left');

# %%
from skopt import gp_minimize

def f_nn(param):
    filters = param[0]
    
    model_nn = Sequential()
    model_nn.add(Conv1D(filters=filters, kernel_size=3, activation='relu', input_shape=(n_steps_in, n_features)))
    model_nn.add(MaxPooling1D(pool_size=2))
    model_nn.add(Flatten())
    # model_nn.add(Dense(10, activation='relu'))
    model_nn.add(Dense(n_outputs))
    model_nn.compile(optimizer='adam', loss='mape')
    # fit model
    history = model_nn.fit(x_train_reshaped, y_train, epochs=80, verbose=0)
    
    x_test_reshaped = x_test.to_numpy().reshape((x_test.shape[0], x_test.shape[1]//n_features, n_features))
    y_pred = model_nn.predict(x_test_reshaped)

    mape = mean_absolute_percentage_error(y_test, y_pred)
    return mape
    
# f = lambda x: x[0]**2-x[0]-1
res = gp_minimize(f_nn,                  # the function to minimize
                  [(32, 128)],      # the bounds on each dimension of x
                  acq_func="EI",      # the acquisition function
                  n_calls=5,         # the number of evaluations of f
                  n_random_starts=2,  # the number of random initialization points
                  initial_point_generator="lhs",
                  n_jobs=-1,
                  random_state=0)   # the random seed

# %%
print(f"x_min = {res['x']}: \nf_min = {res['fun']}")
# res['x_iters']

from skopt.plots import plot_convergence
plot_convergence(res);

# %% [markdown]
# #### Comparaison modèles

# %%
model_ml = [model_xgb, model_rf, model_nn, model_lstm][3]
# y_pred = model_ml.predict(x_test)

x_test_reshaped = x_test.to_numpy().reshape((x_test.shape[0], x_test.shape[1]//n_features, n_features))
y_pred = model_ml.predict(x_test_reshaped)

error = mean_absolute_error(y_test, y_pred)
print(f"mape: {mean_absolute_percentage_error(y_test, y_pred)}")
print(f"mse: {error}")
print(f"y_test_mean: {y_test.mean().values}")
print(f"correlation: {np.corrcoef(y_test.to_numpy().flatten(), y_pred.flatten())[0,1]}")

plt.plot(y_test.reset_index(drop=True))
plt.plot(y_pred)
plt.legend(["test", "pred"]);
# Out:
# mape: 0.24256228466595467
# mse: 0.1523169623331064
# y_test_mean: [0.62859492]
# correlation: -0.07497341729958416

# %% [markdown]
# # Forecast
#
# Once the model is ready, forecasting can be done

# %%
n_forecast = 20  # next steps to forecast
n_last_values = 30  # previous steps to plot

history = x_test.iloc[[-1],:].values[0]
y_forecast = []
for _ in range(n_forecast):
    forecast = model_ml.predict(history.reshape(1,n_previous))[0]
    
    history = np.roll(history, -1)
    history[-1] = forecast
    y_forecast.append(forecast)

df[target].iloc[-n_last_values:].plot(legend=True, figsize=(15,7))
plt.plot(pd.DataFrame(y_forecast, index=list(range(n,n+n_forecast))))
plt.autoscale(axis='x',tight=True)
plt.legend(['observed', 'forecast']);
